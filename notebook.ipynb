# %% [markdown]
# # Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Make the tracknetv3 folder current working directory

# %%
# %cd /content/drive/MyDrive/Shuttlecock/TrackNetV3
# Out:
# /content/drive/MyDrive/Shuttlecock/TrackNetV3

# %% [markdown]
# # Install dependencies

# %%
# !pip install -r requirements.txt
# !pip install filterpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 77.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 112.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 90.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 95.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 11.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Inference with model to get results

# %%
# !python predict_optimized.py --video_file /horizontal.mp4 --tracknet_file /content/drive/MyDrive/Shuttlecock/TrackNetV3/TrackNet_best.pt --inpaintnet_file /content/drive/MyDrive/Shuttlecock/TrackNetV3/InpaintNet_best.pt --save_dir prediction --output_video
# Out:
# ...
# DEBUG INFORMATION
# ...
# Video file: /horizontal.mp4
# Video file exists: True
# TrackNet file: /content/drive/MyDrive/Shuttlecock/TrackNetV3/TrackNet_best.pt
# TrackNet file exists: True
# InpaintNet file: /content/drive/MyDrive/Shuttlecock/TrackNetV3/InpaintNet_best.pt
# InpaintNet file exists: True
# Save directory: prediction
# Output video: True
# Large video mode: False
# Batch size: 16
# Eval mode: weight
# Max frames limit: None
# ...
# [DEBUG] Output CSV will be: prediction/horizontal_ball.csv
# [DEBUG] Output video will be: prediction/horizontal.mp4
# [DEBUG] Save directory already exists: prediction
# [DEBUG] Checking imports...
# [DEBUG] ✓ test module imported successfully
# [DEBUG] ✓ dataset module imported successfully
# [DEBUG] ✓ utils.general module imported successfully
# [DEBUG] WIDTH = 512, HEIGHT = 288
# [DEBUG] Loading TrackNet model...
# [DEBUG] ✓ TrackNet checkpoint loaded
# [DEBUG] TrackNet sequence length: 8
# [DEBUG] Background mode: concat
# ...

# %% [markdown]
# # Go to prediction folder inside the tracknetv3 folder to see the output csv and video file
